# %% [markdown]
# ### Import libraries

# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup

# %% [markdown]
# ### CSV

# %% [markdown]
# The manager of the loanfirm has some user-specific data that we wants us to enhance with extra information. In the end we should have our user data enhanced with the per capita income on a county level which can be found here:
# https://en.wikipedia.org/wiki/List_of_United_States_counties_by_per_capita_income

# %% [markdown]
# There are however some steps we need to complete first. First off all the data is scattered over a number of csv files. Let's import all of them and combine them into one masterfile

# %% [markdown]
# Use the os module to get all the filesnames

# %%
# should add an extra slide in csv's for paths

import os

file_names = os.listdir('../raw_data/adresses')
file_names
# Out:
# ['az.csv',
#  'wa.csv',
#  'nv.csv',
#  'or.csv',
#  'ak.csv',
#  'ca.csv',
#  'id.csv',
#  'hi.csv',
#  'co.csv',
#  'nm.csv',
#  'mt.csv']

# %% [markdown]
# Let's combine them with the proper path so that we can read the csv's.

# %%
file_paths = []

for name in file_names:
    file_paths.append('../raw_data/adresses/' + name)
    
file_paths
# Out:
# ['../raw_data/adresses/az.csv',
#  '../raw_data/adresses/wa.csv',
#  '../raw_data/adresses/nv.csv',
#  '../raw_data/adresses/or.csv',
#  '../raw_data/adresses/ak.csv',
#  '../raw_data/adresses/ca.csv',
#  '../raw_data/adresses/id.csv',
#  '../raw_data/adresses/hi.csv',
#  '../raw_data/adresses/co.csv',
#  '../raw_data/adresses/nm.csv',
#  '../raw_data/adresses/mt.csv']

# %% [markdown]
# Now that we have the proper path in a variable we can loop over them to read our csv's. We would however like to save them in one variable all at once.
#
# Let's loop over all of them and save them in a dictionary structure where
# - **key = filename**
# - **value = dataframe**
#
# Use *nrows=10* to limit the size of our dataset

# %%
diction = {}

for name, path in zip(file_names, file_paths):
    diction[name] = pd.read_csv(path, nrows=10)

# %%
for name, path in zip(file_names, file_paths):
    diction[name] = pd.read_csv(path, nrows=10)

# %% [markdown]
# We can use **pd.concat()** to concatenate our dataframes into one

# %%
full_df = pd.concat(diction.values())

# %%
full_df.shape
# Out:
# (110, 11)

# %%
full_df.head()
# Out:
#           LON        LAT  NUMBER          STREET UNIT CITY  DISTRICT REGION  \
# 0 -111.572316  35.236722  6110.0    N HIGHWAY 89  NaN  NaN       NaN    NaN
# 1 -111.672107  35.233690  3111.0    W SHANNON DR  NaN  NaN       NaN    NaN
# 2 -111.655159  35.215620  1380.0  N ROCKRIDGE RD  NaN  NaN       NaN    NaN
# 3 -111.628072  35.213824  2200.0     N GEMINI DR  NaN  NaN       NaN    NaN
# 4 -111.602377  35.213094  3101.0      E LEWIS DR  NaN  NaN       NaN    NaN
#
#    POSTCODE   ID              HASH
# 0   86004.0  NaN  ec074bdfa4581255
# 1   86001.0  NaN  a7d9e14ded9387d9
# 2   86001.0  NaN  6483fb4f4c44a89c
# 3   86004.0  NaN  6ebc625bcc95e169
# 4   86004.0  NaN  0de30a0ef7c77856

# %% [markdown]
# If we check our null values we see that we're missing quite some data. Also the data is not on the county level.

# %%
full_df.isnull().sum()/len(full_df)
# Out:
# LON         0.000000
# LAT         0.000000
# NUMBER      0.009091
# STREET      0.036364
# UNIT        0.900000
# CITY        0.263636
# DISTRICT    1.000000
# REGION      0.727273
# POSTCODE    0.454545
# ID          0.818182
# HASH        0.000000
# dtype: float64

# %% [markdown]
# ### API

# %% [markdown]
# The great part is however that the latitude and lonitude are present in all row. So we can use an API to get the county data with these lat and lon columns
#
# Documentation:
# https://nominatim.org/release-docs/develop/api/Overview/
#
# Looking at the documentation we spot that we need to use the **endpoint /reverse**
#
# https://nominatim.org/release-docs/develop/api/Reverse/

# %% [markdown]
# Let's construct our URL based on this information:

# %%
base_url = 'https://nominatim.openstreetmap.org'

endpoint = '/reverse'

full_url = base_url + endpoint

full_url
# Out:
# 'https://nominatim.openstreetmap.org/reverse'

# %% [markdown]
# We have three params we could use namely **lat** and **lon**, which we will get from our DF, and **format** which will be fixed on json

# %% [markdown]
# Let's create a function that will send a *GET-request* for a given LAT and LON value and return the county

# %%
import numpy as np

def get_county(lon, lat):
    
    #define params
    params = {
        'lat': lat,
        'lon' : lon,
        'format' : 'json'
    }
    
    #send get request
    response = requests.get(full_url, params).json()
    
    #go through dictionary to get to the county
    if 'county' in response['address'].keys():
        county = response['address']['county']
        
        #replace county for wikipedia mach
        county_clean = county.replace(' County', '')
    else:
        county_clean = np.nan    
    
    #return county_clean
    return county_clean

# %%
get_county(-111.5723157, 35.2367222)
# Out:
# 'Coconino'

# %% [markdown]
# We can now use this function and the **.iterrows()** method to loop over our DF and create an extra columns with the county

# %%
county_ls = []

for index, row in full_df.iterrows():
    county = get_county(row['LON'], row['LAT'])
    county_ls.append(county)

# %% [markdown]
# Now can add a new column with the county data

# %%
full_df['county'] = county_ls
full_df.county.value_counts()
# Out:
# Coconino      10
# Whatcom       10
# Baker         10
# Anchorage     10
# Alameda       10
# Ada           10
# Honolulu      10
# Rio Blanco    10
# Sandoval       4
# Valencia       3
# Custer         3
# McKinley       2
# Deer Lodge     2
# Lincoln        2
# Eddy           1
# Rosebud        1
# Toole          1
# Sheridan       1
# Name: county, dtype: int64

# %% [markdown]
# ### Scraping

# %% [markdown]
# We can use these counties now to get the Per Capita Income
#
# Let's first get a list of all unique counties in our dataset

# %%
counties = full_df.county.unique()
counties
# Out:
# array(['Coconino', 'Whatcom', nan, 'Baker', 'Anchorage', 'Alameda', 'Ada',
#        'Honolulu', 'Rio Blanco', 'McKinley', 'Sandoval', 'Valencia',
#        'Eddy', 'Rosebud', 'Custer', 'Toole', 'Deer Lodge', 'Lincoln',
#        'Sheridan'], dtype=object)

# %% [markdown]
# Let's inspect our webpage and try to identidy a unique class we could scrape

# %%
url_to_scrape = 'https://en.wikipedia.org/wiki/List_of_United_States_counties_by_per_capita_income'

content = requests.get(url_to_scrape).content

soup = BeautifulSoup(content)

# %% [markdown]
# wikitable is the one we need

# %%
table = soup.find('table', class_='wikitable')

# %% [markdown]
# Inside this table we can use **.find_all()** to get all the **tr** elements. We should get a list of all table elements.

# %%
trs = table.find_all('tr')

# %% [markdown]
# Check the first **tr** element and try to figure out how we could get the necessary information out of this.
#
# Watch out for the headers and attribute errors

# %%
cap_dict = {}

for row in trs[1:]:
    try:
        county = row.a.text
        per_capita = row.find_all('td')[3].text
        per_capita_stripped = int(per_capita.lstrip('$').replace(',',''))
        cap_dict[county] = per_capita_stripped
    except AttributeError:
        pass

# %%
cap_dict
# Out:
# {'New York County': 76592,
#  'Arlington': 62018,
#  'Falls Church City': 59088,
#  'Marin': 56791,
#  'Santa Clara': 56248,
#  'Alexandria City': 54608,
#  'Pitkin': 51814,
#  'Los Alamos': 51044,
#  'Fairfax County': 50532,
#  'Hunterdon': 50349,
#  'Borden': 50042,
#  'Montgomery': 15523,
#  'Morris': 20045,
#  'Fairfield': 20257,
#  'San Francisco': 48486,
#  'Howard': 18707,
#  'Westchester': 47984,
#  'Somerset': 16748,
#  'Nantucket': 47331,
#  'Loudoun': 46565,
#  'North Slope': 46457,
#  'San Mateo': 45732,
#  'Kalawao': 45515,
#  'Washington City': 45290,
#  'Goochland': 45039,
#  'Norfolk': 44692,
#  'Fairfax City': 44345,
#  'Douglas': 16404,
#  'Teton': 22436,
#  'Bergen': 43347,
#  'Middlesex': 30531,
#  'Monmouth': 42749,
#  'Summit': 27818,
#  'Nassau': 28926,
#  'Mineral': 19788,
#  'Chester': 18098,
#  'Ozaukee': 42041,
#  'Clear Creek': 41716,
#  'Williamson': 23605,
#  'San Miguel': 17926,
#  'Anne Arundel': 40415,
#  'Putnam': 18377,
#  'Newport': 40293,
#  'Delaware County': 20854,
#  'King': 29836,
#  'Fauquier': 39600,
#  'Hamilton': 16295,
#  'Eagle': 39497,
#  'James City County': 39133,
#  'Bristol': 28837,
#  'Johnson': 16470,
#  'Clarke': 18066,
#  'Williams': 21350,
#  'DuPage': 38570,
#  'Poquoson City': 38444,
#  'Rockingham': 21102,
#  'Calvert': 38260,
#  'Contra Costa': 38219,
#  "Queen Anne's": 38108,
#  'Gilpin': 38022,
#  'Talbot': 16993,
#  'Lake': 12042,
#  'Boulder': 38011,
#  'Billings': 37972,
#  'Sussex': 16546,
#  'Connecticut': 37892,
#  'Collin': 37839,
#  'San Juan': 15476,
#  'Litchfield': 37667,
#  'Waukesha': 37577,
#  'Juneau': 23343,
#  'Hennepin': 37485,
#  'Boone': 21627,
#  'Bucks': 37466,
#  'Mercer': 20178,
#  'Carver': 37457,
#  'Broomfield': 37442,
#  'Prince William': 37401,
#  'Charles': 37277,
#  'Albemarle': 37239,
#  'Skagway': 37139,
#  'Bristol Bay': 37024,
#  'Washington County': 16671,
#  'Suffolk': 32835,
#  'Frederick': 30112,
#  'St. Johns': 36836,
#  'Burlington': 36835,
#  'Fulton': 18602,
#  'Stafford': 23240,
#  'Rappahannock': 36505,
#  'Oakland': 36458,
#  'Collier': 36439,
#  'York': 26553,
#  'Hinsdale': 36365,
#  'Maryland': 36354,
#  'Divide': 36303,
#  'Anchorage': 36214,
#  'Roberts': 22670,
#  'Union': 13590,
#  'Carroll': 16897,
#  'Barnstable': 36142,
#  'Jefferson': 12723,
#  'Elbert': 18835,
#  'New Jersey': 36027,
#  "St. Mary's": 36017,
#  'Sublette': 35944,
#  'Dallas': 16838,
#  'Kendall': 31276,
#  'Massachusetts': 35763,
#  'Alameda': 35763,
#  'Blaine': 17437,
#  'Scott': 16789,
#  'Harford': 35425,
#  'Fayette': 18494,
#  'Denali': 35295,
#  'Plymouth': 27942,
#  'Saratoga': 35176,
#  'Essex': 20887,
#  'Platte': 24219,
#  'Placer': 34886,
#  'El Dorado': 34884,
#  'Routt': 34873,
#  'Lincoln': 15023,
#  'Dakota': 20179,
#  'Napa': 34795,
#  'St. Louis County': 25946,
#  'Hartford': 34698,
#  'Rockwall': 34617,
#  'Rockland': 34591,
#  'Forsyth': 26541,
#  'Orange': 18576,
#  'Geauga': 34455,
#  'Tolland': 34392,
#  'Hillsborough': 27149,
#  'Baltimore County': 34374,
#  'Yakutat': 34317,
#  'King George': 34234,
#  'Petersburg Census Area': 34183,
#  'Fort Bend': 34084,
#  'Olmsted': 34073,
#  'Loving': 34068,
#  'Martin': 15525,
#  'Monroe': 15749,
#  'Denton': 33855,
#  'Campbell': 16812,
#  'Kent': 24839,
#  'Mountrail': 33803,
#  'Oconee': 23904,
#  'Dunn': 22499,
#  'New London': 33782,
#  'Dane': 33712,
#  'Midland': 29536,
#  'Llano': 33634,
#  'Columbia': 19306,
#  'Dutchess': 33594,
#  'Oldham': 22519,
#  'Warren': 17884,
#  'Hanover': 33540,
#  'Virginia': 33493,
#  'Storey': 33472,
#  'Dukes': 33363,
#  'Towner': 33357,
#  'Shelby': 19331,
#  'Chittenden': 33281,
#  'Denver': 33251,
#  'Washtenaw': 33231,
#  'Travis': 33206,
#  'Madison': 13585,
#  'Wake': 33166,
#  'Grand Isle': 33159,
#  'New Hampshire': 33134,
#  'Henrico': 33115,
#  'McKenzie': 33078,
#  'Cobb': 33069,
#  'Foster': 33063,
#  'Ouray': 33015,
#  'Comal': 32980,
#  'Cape May': 32948,
#  'Ventura': 32930,
#  'Burke': 16171,
#  'Worcester': 31537,
#  'Cumberland': 17697,
#  'Burleigh': 32876,
#  'Cook': 18592,
#  'Palm Beach': 32858,
#  'Sonoma': 32835,
#  'Clackamas': 32781,
#  'Alaska': 32651,
#  'Greeley': 23833,
#  'Hudson': 32641,
#  'Gloucester': 28673,
#  'Arapahoe': 32595,
#  'Valdez-Cordova Census Area': 32579,
#  'Chesterfield': 17140,
#  'New Haven': 32523,
#  'Sitka': 32521,
#  'Beaufort': 21636,
#  'Botetourt': 32490,
#  'Mecklenburg': 20056,
#  'New Castle': 32406,
#  'New York': 32382,
#  'Nevada County': 18695,
#  "Prince George's": 32344,
#  'McHenry': 28331,
#  'Albany': 24758,
#  'Sarasota': 32313,
#  'Santa Fe': 32298,
#  'Santa Cruz': 17664,
#  'Oliver': 32253,
#  'St. Croix': 32220,
#  'Fairbanks North Star': 32143,
#  'Livingston': 19795,
#  'New Kent': 32068,
#  'Bowman': 32045,
#  'Richland': 18669,
#  'Cavalier': 32028,
#  'LaMoure': 31989,
#  'Bottineau': 31969,
#  'Virginia Beach City': 31934,
#  'Richmond': 17236,
#  'Aleutians West Census Area': 31790,
#  'Dickinson': 23895,
#  'Kitsap': 31769,
#  'Roanoke County': 31728,
#  'Barnes': 31721,
#  'Lane': 24224,
#  'Grand': 23558,
#  'Allegheny': 31593,
#  'Ketchikan Gateway': 31589,
#  'St. Charles': 26756,
#  'Terrell': 16836,
#  'Sioux': 15478,
#  'Park': 24611,
#  'Adams': 16940,
#  'Harris': 27899,
#  'Leelanau': 31462,
#  'Steele': 27259,
#  'Daniels': 31449,
#  'Stark': 24453,
#  'Sheridan': 22551,
#  'Spotsylvania': 31360,
#  'Snohomish': 31349,
#  'Mathews': 31342,
#  'Merrimack': 31310,
#  'Miner': 31288,
#  'Kenai Peninsula': 31256,
#  'Powhatan': 31252,
#  'Piatt': 31190,
#  'Renville': 26062,
#  'Chatham': 25093,
#  'Grundy': 15683,
#  'Glasscock': 31135,
#  'Colorado': 31109,
#  'Haines': 31096,
#  'Teller': 31075,
#  'McLean': 19984,
#  'Butler': 17403,
#  'Converse': 30941,
#  'Island': 30941,
#  'Stanley': 30933,
#  'Windsor': 30932,
#  'Woodford': 29277,
#  'Galveston': 30926,
#  'Audubon': 30919,
#  'Minnesota': 30913,
#  'Isle of Wight': 30903,
#  'Fluvanna': 30881,
#  'Washington': 30742,
#  'Larimer': 30740,
#  'Grafton': 30738,
#  'Lancaster': 21003,
#  'Medina': 22413,
#  'Parker': 30692,
#  'San Diego': 30668,
#  'Door': 30657,
#  'Anoka': 30647,
#  'Camden': 22701,
#  'Slope': 30586,
#  'Indian River': 30532,
#  'Dare': 30529,
#  'Cass': 20104,
#  'Belknap': 30518,
#  'Sweetwater': 30517,
#  'Ocean': 30477,
#  'Multnomah': 30475,
#  'Rhode Island': 30469,
#  'Polk': 18336,
#  'Ulster': 30442,
#  'Hodgeman': 30440,
#  'Nelson': 23545,
#  'Will': 30377,
#  'St. Tammany': 30363,
#  'Honolulu': 30361,
#  'Santa Barbara': 30352,
#  'Hughes': 18268,
#  'Ness': 30223,
#  'Sully': 30218,
#  'Sarpy': 30189,
#  'Charleston': 30158,
#  'La Plata': 30151,
#  'Chambers': 19291,
#  'Gillespie': 30117,
#  'Thomas': 19983,
#  'Wheeler': 8948,
#  'Kane': 24154,
#  'Hood': 30046,
#  'Greene': 14463,
#  'Saunders': 30039,
#  'Goliad': 30031,
#  'Rensselaer': 29987,
#  'Sangamon': 29974,
#  'San Luis Obispo': 29954,
#  'Sargent': 29950,
#  'Linn': 21015,
#  'Goodhue': 29932,
#  'Warrick': 29927,
#  'Chesapeake City': 29905,
#  'Ontario': 29904,
#  'Natrona': 29877,
#  'Hendricks': 29830,
#  'Delaware': 29819,
#  'Plumas': 29806,
#  'Lander': 29800,
#  'Archuleta': 29793,
#  'Thurston': 17106,
#  'North Dakota': 29732,
#  'Emmet': 27908,
#  'New Hanover': 29679,
#  'Jo Daviess': 29675,
#  'Illinois': 29666,
#  'Wright': 14752,
#  'Cherokee': 18240,
#  'Montour': 29600,
#  'Cameron': 14710,
#  'Hemphill': 29544,
#  'Matanuska-Susitna': 29534,
#  'California': 29527,
#  'Cecil': 29518,
#  'Maui': 29517,
#  'Ramsey': 28081,
#  'Hampshire': 17734,
#  'Southeast Fairbanks Census Area': 29437,
#  'Clay': 12982,
#  'Morton': 22378,
#  'Strafford': 29369,
#  'Durham': 29347,
#  'Calaveras': 29329,
#  'Hawaii': 29305,
#  'Wells': 24269,
#  'Berkshire': 29294,
#  'Northampton': 17919,
#  'Pinellas': 29262,
#  'Franklin': 17620,
#  'Dauphin': 29234,
#  'Bennington': 29196,
#  'Posey': 29187,
#  'Vermont': 29167,
#  'Suffolk City': 29135,
#  'Pope': 19918,
#  'Kossuth': 29127,
#  'Randall': 29124,
#  'Dodge': 18114,
#  'Brazoria': 29081,
#  'Walsh': 29072,
#  'Lipscomb': 29017,
#  'Gallatin': 19020,
#  'Solano': 28929,
#  'Moore': 19770,
#  'Calumet': 28907,
#  'Kidder': 28904,
#  'Wyoming': 28902,
#  'Lafayette': 17212,
#  'Stillwater': 28868,
#  'El Paso': 18379,
#  'Windham': 27893,
#  'Sagadahoc': 28829,
#  'DeKalb': 16635,
#  'Hoonah-Angoon Census Area': 28806,
#  'Salem': 28772,
#  'Weston': 28764,
#  'Clermont': 28761,
#  'Manassas City': 28752,
#  'Onondaga': 28746,
#  'Stevens': 21986,
#  'Bremer': 28727,
#  'Addison': 28722,
#  'Bath': 16367,
#  'Bedford County': 28697,
#  'Seminole': 17641,
#  'Washoe': 28670,
#  'Porter': 28669,
#  'Okaloosa': 28600,
#  'Benton': 18456,
#  'Sullivan': 19279,
#  'Northumberland': 22478,
#  'Fallon': 28563,
#  'Kodiak Island': 28562,
#  'Ward': 22278,
#  'Powder River': 28528,
#  'Laramie': 28505,
#  'Pennsylvania': 28502,
#  'Dundy': 28502,
#  'Wrangell': 28474,
#  'Davidson': 22549,
#  'Clinton': 16795,
#  'Skamania': 28449,
#  'Peoria': 28438,
#  'Eddy': 27323,
#  'Miami': 20475,
#  'Lewis and Clark': 28400,
#  'Seward': 19015,
#  'Elko': 28358,
#  'Custer': 23261,
#  'Menard': 18253,
#  'Schenectady': 28319,
#  'Washakie': 28308,
#  'Cheyenne': 23647,
#  'Wabasha': 28282,
#  'Tarrant': 28266,
#  'Chase': 21775,
#  'Pierce': 20001,
#  'Crook': 20883,
#  'Broward': 28205,
#  'Outagamie': 28186,
#  'Ascension': 28178,
#  'Kanawha': 28174,
#  'United States': 28155,
#  'Graham': 17168,
#  'Knox': 14367,
#  'Somervell': 28134,
#  'Grant': 19018,
#  'Hancock': 12381,
#  "O'Brien": 28086,
#  'Sherburne': 28071,
#  'Iowa County': 26625,
#  'Eureka': 28056,
#  'Irion': 28055,
#  'Westmoreland': 25245,
#  'Mono': 28046,
#  'Tazewell': 21358,
#  'Guthrie': 28030,
#  'Traverse': 28030,
#  'Baylor': 28021,
#  'Lac qui Parle': 28014,
#  'Ottawa': 18331,
#  'Erie': 24189,
#  'Perkins': 25751,
#  'Lehigh': 27923,
#  'Chisago': 27914,
#  'Hettinger': 27910,
#  'Logan': 19046,
#  'Clark': 17960,
#  'Cheshire': 27874,
#  'Wilson': 19929,
#  'Pembina': 27817,
#  'Archer': 27800,
#  'Kearney': 27796,
#  'Brewster': 27796,
#  'Sumner': 22972,
#  'Le Sueur': 27793,
#  'Brown': 20555,
#  'Yellowstone': 27761,
#  'Spink': 27757,
#  'Los Angeles': 27749,
#  'Yolo': 27730,
#  'Sutton': 27721,
#  'Kenton': 27704,
#  'Pike': 18183,
#  'Emmons': 27690,
#  'Moody': 27682,
#  'Tulsa': 27676,
#  'Grand Traverse': 27660,
#  'Gunnison': 27654,
#  'Coffey': 27627,
#  'Colonial Heights City': 27610,
#  'Marathon': 27607,
#  'Carbon': 20155,
#  'Rio Blanco': 27586,
#  'Bryan': 20524,
#  'Canadian': 27552,
#  'Deuel': 27199,
#  'Deschutes': 27524,
#  'Wisconsin': 27523,
#  'East Baton Rouge': 27505,
#  'Sumter': 14156,
#  'Mason': 20622,
#  'Kimble': 27502,
#  'Lawrence': 14147,
#  'Carteret': 27496,
#  'Wibaux': 27492,
#  'Kingsbury': 27485,
#  'McPherson': 22596,
#  'Ada': 27452,
#  'Murray': 16449,
#  'Inyo': 27441,
#  'Andrews': 27429,
#  'Bossier': 27429,
#  'Cuyahoga': 27423,
#  'Tompkins': 27418,
#  'Pulaski': 17781,
#  'Atlantic': 27391,
#  'Culpeper': 27379,
#  'McMullen': 27375,
#  'Rogers': 27365,
#  'Jackson': 15609,
#  'Bartholomew': 27359,
#  'Stutsman': 27351,
#  'Lee': 12529,
#  'Amador': 27347,
#  'Dawson': 17677,
#  'Roger Mills': 27326,
#  'Manatee': 27322,
#  'Cerro Gordo': 27291,
#  'Yankton': 27268,
#  'Charlottesville City': 27268,
#  'Maricopa': 27256,
#  'Tioga': 22621,
#  'Fredericksburg City': 27222,
#  'Griggs': 27197,
#  'Floyd': 17716,
#  'Richmond City': 27184,
#  'Ellis': 24291,
#  'Chaffee': 27182,
#  'Major': 27168,
#  'McCone': 27161,
#  'Lamoille': 27157,
#  'Decatur': 18059,
#  'Passaic': 27152,
#  'Racine': 27141,
#  'Walworth': 25915,
#  'Henry': 19852,
#  'Mills': 22651,
#  'Traill': 27098,
#  'Lebanon': 27074,
#  'Skagit': 27065,
#  'Green': 17984,
#  'Dearborn': 27058,
#  'Effingham': 24824,
#  'Loudon': 27045,
#  'Oneida': 18920,
#  'Buchanan': 17489,
#  'Iowa': 27027,
#  'Grand Forks': 27026,
#  'Leavenworth': 27017,
#  'Brevard': 27009,
#  'Pennington': 24554,
#  'Mariposa': 26988,
#  'Young': 26979,
#  'Thayer': 26965,
#  'Jeff Davis': 17684,
#  'Louisa': 24272,
#  'Winnebago': 24495,
#  'Garfield': 21989,
#  'Aransas': 26953,
#  'Charlevoix': 26947,
#  'Manassas Park City': 26944,
#  'King William': 26940,
#  'Fremont': 18954,
#  'Kansas': 26929,
#  'Kittson': 26927,
#  'Sandoval': 26924,
#  'Calhoun': 14675,
#  'Cleveland': 20062,
#  'Mitchell': 15694,
#  'Nebraska': 26899,
#  'Rankin': 26897,
#  'Rawlins': 26897,
#  'Lexington': 26886,
#  'Kandiyohi': 26880,
#  'Hays': 26873,
#  'Santa Rosa': 26861,
#  'Phelps': 21173,
#  'Brunswick': 16060,
#  'Marshall': 17978,
#  'Carson': 26827,
#  'McLeod': 26824,
#  'Maine': 26824,
#  'Armstrong': 23661,
#  'Bernalillo': 26814,
#  'Smith': 20334,
#  'Oregon': 26809,
#  'Niobrara': 26797,
#  'Blanco': 26781,
#  'Baldwin': 18622,
#  'Jones': 14827,
#  'Coweta': 26757,
#  'Macomb': 26748,
#  'Humboldt': 23540,
#  'Sacramento': 26739,
#  'Glynn': 26724,
#  'Berks': 26723,
#  'Licking': 26716,
#  'Garden': 26715,
#  'Bureau': 26705,
#  'DeWitt': 23720,
#  'Mesa': 26700,
#  'Pickens': 17153,
#  'Nicollet': 26674,
#  'Spencer': 23641,
#  'Salem City': 26661,
#  'Kauai': 26658,
#  'Greenville': 26643,
#  'Ogle': 26635,
#  'Reagan': 26633,
#  'Jerauld': 26590,
#  'Nevada': 26589,
#  'Schoharie': 26584,
#  'Eaton': 26582,
#  'Cedar': 16362,
#  'Oklahoma County': 26561,
#  'Hot Springs': 26544,
#  'Aleutians East': 26535,
#  'Whatcom': 26530,
#  'Crow Wing': 26527,
#  'Panola': 18073,
#  'Kenosha': 26514,
#  'McCook': 26505,
#  'Orleans': 22255,
#  'Queens': 26495,
#  'Iredell': 26467,
#  'Guilford': 26461,
#  'Rock Island': 26455,
#  'Houston': 18539,
#  'Coke': 26407,
#  'Otter Tail': 26400,
#  'Dorchester': 24495,
#  'Minnehaha': 26380,
#  'Highland County': 26372,
#  'Fond du Lac': 26368,
#  'Sac': 26350,
#  'Lamar': 18800,
#  'Kerr': 26334,
#  'Wood': 23129,
#  'Davie': 26319,
#  'Osborne': 26313,
#  'Providence': 26308,
#  'Charlotte': 18762,
#  'Granite': 26277,
#  'Morgan': 16233,
#  'La Crosse': 26271,
#  'Berkeley': 24165,
#  'Carson City': 26264,
#  'Beaver': 19415,
#  'Dubuque': 26254,
#  'Vilas': 26252,
#  'Florida': 7837,
#  'St. Clair': 17337,
#  'Gove': 26233,
#  'Macon': 13865,
#  'Barber': 26229,
#  'Pratt': 26209,
#  'Rutland': 26205,
#  'Charles City County': 26198,
#  'Leon': 24170,
#  'Hyde': 18408,
#  'Worth': 18551,
#  'Guadalupe': 14198,
#  'Harrison': 19468,
#  'Potter': 19861,
#  'Cole': 26160,
#  'Buncombe': 26159,
#  'Duval': 20181,
#  'Ransom': 26137,
#  'Ohio County': 19005,
#  'Sheboygan': 26126,
#  'Golden Valley': 23508,
#  'Hutchinson': 23383,
#  'Salt Lake': 26103,
#  'Stearns': 26065,
#  'Winchester City': 26060,
#  'Shawnee': 26057,
#  'Perry': 13716,
#  'Ohio': 26046,
#  'Koochiching': 26045,
#  'Davis': 22210,
#  'Lorain': 26030,
#  'Lyon': 19789,
#  'Hand': 26027,
#  'Woods': 26022,
#  'Texas': 26019,
#  'Big Stone': 26019,
#  'Chippewa': 20589,
#  'Niagara': 25991,
#  'Sauk': 25988,
#  'Story': 25986,
#  'Saline': 19006,
#  'McCracken': 25957,
#  'Waupaca': 25956,
#  'Tuolumne': 25943,
#  'Oconto': 25941,
#  'Gwinnett': 25932,
#  'San Benito': 25914,
#  'Henderson': 20449,
#  'Chelan': 25893,
#  'Austin': 25884,
#  'Ida': 25869,
#  'Clallam': 25865,
#  'Otoe': 25855,
#  'Currituck': 25854,
#  'Pottawattamie': 25847,
#  'Monongalia': 25846,
#  'Walton': 22824,
#  'Manitowoc': 25825,
#  'Sanborn': 25823,
#  'Hampden': 25817,
#  'Banner': 25814,
#  'Barton': 20678,
#  'Flathead': 25790,
#  'Sibley': 25789,
#  'Valley': 23227,
#  'Wasatch': 25777,
#  'Edmunds': 25775,
#  'Kingfisher': 25773,
#  'Kennebec': 25770,
#  'Missoula': 25764,
#  'Kalamazoo': 25757,
#  'Haakon': 25754,
#  'Swift': 25750,
#  'Plaquemines': 25748,
#  'South Dakota': 25740,
#  'Saint John': 25730,
#  'Waseca': 25723,
#  'Caroline': 25211,
#  'Champaign': 23358,
#  'LaSalle': 25709,
#  'Harding': 22247,
#  'Michigan': 25681,
#  'Clatsop': 25680,
#  'Freeborn': 25668,
#  'Meeker': 25665,
#  'Wise': 19107,
#  'Spokane': 25661,
#  'Roseau': 25650,
#  'Redwood': 25649,
#  'Missouri': 25649,
#  'Rockbridge': 25638,
#  'Jessamine': 25637,
#  'Watonwan': 25635,
#  'Sedgwick': 21536,
#  'Newton': 17884,
#  'Lackawanna': 25594,
#  'Dubois': 25589,
#  'Codington': 25582,
#  'Adair': 15116,
#  'Hardin': 19626,
#  'Pocahontas': 20373,
#  'Centre': 25545,
#  'Gray': 21738,
#  'Republic': 25531,
#  'Alpine': 25527,
#  'Trigg': 25527,
#  'Liberty': 16266,
#  'Augusta': 25519,
#  'Uinta': 25513,
#  'Isanti': 25482,
#  'Marion': 16531,
#  'Weld': 25468,
#  'Jersey': 25467,
#  'Fillmore': 25249,
#  'Becker': 25455,
#  'Ford': 19994,
#  'Shackelford': 25436,
#  'Wallace': 25429,
#  'McIntosh': 19100,
#  'Pawnee': 21220,
#  'Turner': 17609,
#  'Genesee': 22380,
#  'Blue Earth': 25380,
#  'Wicomico': 25378,
#  'Bayfield': 25377,
#  'Meade': 20898,
#  'White': 18205,
#  'Montana': 25373,
#  'Steuben': 23975,
#  'Rice': 23068,
#  'Bandera': 25364,
#  'Arizona': 25358,
#  'Portage': 24972,
#  'Chemung': 25329,
#  'Wayne': 16396,
#  'Auglaize': 25323,
#  'Harlan': 16257,
#  'Gilliam': 25320,
#  'Poweshiek': 25318,
#  'Tama': 25311,
#  'Newport News City': 25310,
#  'Yellow Medicine': 25303,
#  'Andrew': 25302,
#  'McClain': 25293,
#  'Kings': 18429,
#  'Eau Claire': 25287,
#  'North Carolina': 25284,
#  'Kewaunee': 25282,
#  'Allen': 18857,
#  'Green Lake': 25275,
#  'Pima': 25269,
#  'Nemaha': 24550,
#  'Frontier': 25262,
#  'Keya Paha': 25251,
#  'Cabarrus': 25247,
#  'Hampton City': 25247,
#  'Hamlin': 25233,
#  'Crawford': 18415,
#  'Cherry': 25213,
#  'Burt': 25203,
#  'Cooke': 25186,
#  'Antelope': 25186,
#  'Yavapai': 25186,
#  'Georgia': 25182,
#  'Hood River': 25181,
#  'DeSoto': 15088,
#  'Wilkin': 25148,
#  'Christian': 19773,
#  'Shenandoah': 25134,
#  'Big Horn': 15695,
#  'Haskell': 18896,
#  'Amelia': 25100,
#  'Iroquois': 25098,
#  'Keith': 25097,
#  'Tipton': 23054,
#  'Rutherford': 19551,
#  'Clayton': 17950,
#  'Faribault': 25065,
#  'Winneshiek': 25062,
#  'Barry': 19489,
#  'Palo Alto': 25055,
#  'Box Butte': 25046,
#  'Muscatine': 25038,
#  'Limestone': 19352,
#  'Trempealeau': 25017,
#  'Burnet': 24998,
#  'Sierra': 17752,
#  'Mower': 24990,
#  'Kaufman': 24954,
#  'Aitkin': 24939,
#  'Garrett': 24932,
#  'St. James': 24930,
#  'Allamakee': 24926,
#  'Woodward': 24922,
#  'Carter': 18245,
#  'Jasper': 17350,
#  'Pottawatomie': 20937,
#  'Kosciusko': 24881,
#  'Hubbard': 24880,
#  'De Baca': 24879,
#  'Wagoner': 24874,
#  'Dewey': 15558,
#  'Alachua': 24857,
#  'Washburn': 24850,
#  'West Baton Rouge': 24838,
#  'Sherman': 21476,
#  'Broome': 24835,
#  'Benzie': 24831,
#  'Buffalo': 11405,
#  'Keweenaw': 24802,
#  'Lafourche': 24798,
#  'Luzerne': 24793,
#  'Osage': 22353,
#  'Schleicher': 24787,
#  'Ballard': 24781,
#  'Monterey': 24775,
#  'Delta': 20150,
#  'Aiken': 24769,
#  'Ingham': 24754,
#  'Staunton City': 24753,
#  'Baltimore City': 24750,
#  'Atchison': 21909,
#  'San Jacinto': 24733,
#  'Cascade': 24727,
#  'Churchill': 24716,
#  'Edwards': 20898,
#  'Cayuga': 24702,
#  'Victoria': 24700,
#  'Montague': 24699,
#  'Kootenai': 24685,
#  'Russell': 17107,
#  'Norfolk City': 24659,
#  'Asotin': 24659,
#  'Macoupin': 24658,
#  'Osceola': 18099,
#  'Dickey': 24644,
#  'Merrick': 24639,
#  'Hawaii County': 24635,
#  'Indiana': 24635,
#  'Whitley': 15960,
#  'Davison': 24597,
#  'Prince of Wales-Hyder Census Area': 24581,
#  'Moffat': 24577,
#  'Autauga': 24571,
#  'Hartley': 24566,
#  'Kimball': 24565,
#  'Anderson': 18495,
#  'Franklin County': 24557,
#  'Monona': 24557,
#  'Gage': 24555,
#  'Ray': 24549,
#  'Haywood': 18714,
#  'Boyd': 23157,
#  'Whiteside': 24525,
#  'Rock': 24094,
#  'Bay': 23799,
#  'Flagler': 24497,
#  'Cuming': 24496,
#  'Susquehanna': 24477,
#  'Yates': 24457,
#  'Androscoggin': 24442,
#  'Louisiana': 24442,
#  'Georgetown': 24437,
#  'White Pine': 24435,
#  'Prince George': 24434,
#  'Carlton': 24434,
#  'Fergus': 24429,
#  'Tennessee': 24409,
#  'Des Moines': 24408,
#  'Faulkner': 24401,
#  'Vanderburgh': 24378,
#  'Antrim': 24370,
#  'Pepin': 24367,
#  'Coos': 22239,
#  'Calcasieu': 24355,
#  'Colorado County': 24348,
#  'Jack': 24325,
#  'Boise': 24324,
#  'Otsego': 24165,
#  'Bullitt': 24308,
#  'Caddo': 17858,
#  'Lavaca': 24299,
#  'Milwaukee': 24295,
#  'Yamhill': 24290,
#  'Black Hawk': 24273,
#  'Broadwater': 24270,
#  'Guaynabo': 24264,
#  'Craven': 24260,
#  'Judith Basin': 24260,
#  'Rich': 24258,
#  'Gibson': 20402,
#  'Nez Perce': 24257,
#  'Bexar': 24253,
#  'Ector': 24247,
#  'Oklahoma': 24208,
#  'Webster': 17937,
#  'Wabaunsee': 24199,
#  'Wyoming County': 18377,
#  'Rush': 23396,
#  'Schuyler': 18160,
#  'Paulding': 22714,
#  'Alleghany': 19510,
#  'Allegan': 24140,
#  'Chickasaw': 16677,
#  'Pipestone': 24137,
#  'Holt': 24120,
#  'Terrebonne': 24114,
#  'Wabash': 21201,
#  'Throckmorton': 24086,
#  'Itasca': 24079,
#  'Gregg': 24064,
#  'Stonewall': 24063,
#  'Huerfano': 24058,
#  'Kingman': 24026,
#  'Beadle': 24025,
#  'Berrien': 16784,
#  'Grayson': 19115,
#  'Horry': 24002,
#  'Lemhi': 23998,
#  'Bosque': 23992,
#  'Owen': 21318,
#  'Mahoning': 23975,
#  'Volusia': 23973,
#  'Curry': 21259,
#  'Hansford': 23969,
#  'Beckham': 23959,
#  'Treasure': 23948,
#  'South Carolina': 23943,
#  'Roane': 17341,
#  'Lapeer': 23907,
#  'Penobscot': 23895,
#  'Pacific': 23888,
#  'Lucas': 21126,
#  'Blair': 23875,
#  'Utah': 23873,
#  'Crockett': 18664,
#  'King and Queen': 23868,
#  'Elmore': 20646,
#  'Pickaway': 23851,
#  'Washita': 23811,
#  'Robertson': 17641,
#  'Walla Walla': 23809,
#  'Perquimans': 23809,
#  'Sawyer': 23809,
#  'Uintah': 23805,
#  'Wichita': 22837,
#  'Taylor': 17045,
#  'Marquette': 23490,
#  'Mahaska': 23788,
#  'Blount': 20730,
#  'Butte': 20995,
#  'Moultrie': 23786,
#  'Dinwiddie': 23781,
#  'Kankakee': 23779,
#  'Harvey': 23775,
#  ...}

# %% [markdown]
# We can now use the .map() function to enrich our dataset

# %%
full_df['per_capita'] = full_df.county.map(cap_dict)

# %%
full_df.per_capita.isnull().sum()
# Out:
# 10
